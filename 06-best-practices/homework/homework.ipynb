# %% [markdown]
# ### Problem 1

# %% [markdown]
# ### Problem 2

# %% [markdown]
# ### Problem 3

# %% [markdown]
# After running the prepare_data on the example data in the unit test, the dataframe should have only 2 rows. This is the second option, or B.

# %% [markdown]
# ### Problem 4

# %% [markdown]
# ### Problem 5

# %% [markdown]
# After starting the s3 service, making the nyc-duration bucket, and writing the test dataframe to s3 via the integration test, the written file size was 3504 (close enough to 3512). The answer is the first option, or A.

# %% [markdown]
# ### Problem 6

# %% [markdown]
# After adding save_data, running batch.py with the test data, and then reading the output file back in, the sum of the durations is 69.29. This is close to 69.28 which is the third option, or C.
