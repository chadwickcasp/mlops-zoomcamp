# %%
from pymongo import MongoClient
import pprint
from prefect_monitoring import MONGO_CLIENT_ADDRESS, MONGO_DATABASE

client = MongoClient(MONGO_CLIENT_ADDRESS)
dbm = client.get_database(MONGO_DATABASE)
print(dbm.list_collection_names())
print(dbm.get_collection('report').count_documents({}))

# collection = client.get_database(MONGO_DATABASE).get_collection('report')

# print(collection)
# Out:
# ['report', 'data']
# 2
