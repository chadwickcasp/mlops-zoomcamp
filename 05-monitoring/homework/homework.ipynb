# %% [markdown]
# ### Problem 1

# %% [markdown]
# When I access the typical MongoDB address at http://localhost:27017 it doesn't connect. Which is most similar to: It looks like you're trying to access MongoDB over HTTP on the dative driver port (B, or second option).

# %% [markdown]
# ### Problem 2

# %% [markdown]
# The Docker command to find the names of the volumes is: `docker volume ls` (D, or fourth option).

# %% [markdown]
# ### Problem 3

# %% [markdown]
# The final value in the stream of predictions we send to the prediction service is 15.74 (B, or second option)

# %% [markdown]
# ### Problem 4

# %% [markdown]
# When we check how many features have drifted from 05-2021 predictions to the 03-2021 reference predictions, we find 2 features have drifted )(running prefect_monitoring.py) (B, or second option)

# %% [markdown]
# ### Problem 5

# %% [markdown]
# Inspecting the HTML report generated by Evidently, we find that Jensen-Shannon distance is used for the stats tests for the location IDs

# %% [markdown]
# ### Problem 6

# %% [markdown]
# Changing the model, clearing the MongoDB database, and re-running the data stream script (send_data.py), we get 16.64 as the final streamed prediction. (B, or second option)

# %% [markdown]
# ### Problem 7

# %% [markdown]
# ### Problem 8
