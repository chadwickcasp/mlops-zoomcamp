# %% [markdown]
# # Homework Section 3 - Orchestration

# %% [markdown]
# ### Problem 1

# %% [markdown]
# It's 16.19 (B, or second option)

# %% [markdown]
# ### Problem 2

# %% [markdown]
# It's 19M (B, or second option)

# %% [markdown]
# ### Problem 3

# %% [markdown]
# ```bash
# jupyter nbconvert --to script homework.ipynb
# ```

# %% [markdown]
# ### Problem 4

# %% [markdown]
# sha256:08ef968f6b72033c16c479c966bf37ccd49b06ea91b765e1cc27afefe723920b

# %% [markdown]
# ### Problem 5

# %% [markdown]
# It's 16.29 (B, or second option)

# %% [markdown]
# ### Problem 6

# %% [markdown]
# It's 9.96 (A, or first option)

# %% [markdown]
# ### Bonus

# %% [markdown]
# Modifications made in ```starter.py```:
#
# ```python
# s3 = boto3.client('s3')
# ```
# ...
# ```python
#     key = f'predictions/{year:04d}/{month:02d}/{output_file}'
#     s3.upload_file(
#         output_file,
#         'mlflow-artifacts-remote433',
#         key
#     )
# ```
#
# And used the following commands to build and run the container:
#
# ```bash
# docker build --platform=linux/amd64 -t homework:v1 --load .
# docker run --rm \
#   --platform linux/amd64 \
#   -v "$HOME/.aws:/root/.aws:ro" \
#   -e AWS_DEFAULT_REGION=us-west-1 \
#   homework:v1 \
#   --year 2021 \
#   --month 4
# ```
