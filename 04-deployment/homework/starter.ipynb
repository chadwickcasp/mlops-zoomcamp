# %%
# !pip freeze | grep scikit-learn
# Out:
# scikit-learn @ file:///Users/runner/miniforge3/conda-bld/scikit-learn_1640464197365/work

# %%
import pickle
import pandas as pd

# %%
with open('model.bin', 'rb') as f_in:
    dv, lr = pickle.load(f_in)

# %%
categorical = ['PUlocationID', 'DOlocationID']

def read_data(filename):
    df = pd.read_parquet(filename)
    
    df['duration'] = df.dropOff_datetime - df.pickup_datetime
    df['duration'] = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)].copy()

    df[categorical] = df[categorical].fillna(-1).astype('int').astype('str')
    
    return df

# %%
# df = read_data('https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_????-??.parquet')
df = read_data('https://d37ci6vzurychx.cloudfront.net/trip-data/fhv_tripdata_2021-02.parquet')

# %%
dicts = df[categorical].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = lr.predict(X_val)

# %%
print(y_pred.mean())
# Out:
# 16.191691679979066

# %%
year = 2021
month = 2

df['ride_id'] = f'{year:04d}/{month:02d}_'+df.index.astype('str')
df_result = pd.DataFrame()
df_result['ride_id'] = df['ride_id']
df_result['predicted_duration'] = y_pred
output_file = f'results_{year:04d}_{month:02d}.parquet'
df_result.to_parquet(
    output_file,
    engine='pyarrow',
    compression=None,
    index=False
)
